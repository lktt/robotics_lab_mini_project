# %%
# Checking GPU Status
# !nvidia-smi
# Out:
# /bin/bash: nvidia-smi: command not found

# %%
# Setting Our Directory
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# Installing The YOLOv8 Training Resources
# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()

import torch
from ultralytics import YOLO
from IPython.display import display, Image, clear_output
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.4/78.2 GB disk)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="dFYPWhqjJ6oYhG3iO2Qs")
project = rf.workspace("king-mongkuts-institute-of-technology-ladkrabang-8s2t3").project("face-mask-detection-prvd3")
dataset = project.version(1).download("yolov8")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Face-Mask-Detection-1 in yolov8:: 100%|██████████| 156/156 [00:00<00:00, 2664.30it/s]

# %%
# !yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml imgsz=640 plots=True
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
